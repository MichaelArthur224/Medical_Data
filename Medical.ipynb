# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv (r'C:\Users\Michael\Downloads\medical.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# # Plot a histogram with a kde (kernel density estimate)

# %%
#The features to analyze: VitD_levels, Doc_visits, TotalCharge

# %% [markdown]
# # VitD_levels

# %%
sns.kdeplot(data = df,  x='VitD_levels');

# %%
#Add a line for the mean (red)
mean = df['VitD_levels'].mean()
#Add a line for the median (green)
med = df['VitD_levels'].median()
std = df['VitD_levels'].std()
#Add a line for for +1 std from the mean (black)
plus_one_std = mean + std
#Add a line for the - 1 std from the mean (black)
minus_one_std = mean - std
#Highlight the range between +1 and =1 std (yellow)

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(df['VitD_levels'] ,ax=ax, stat='probability')
ax.axvline(mean, color = 'red', label='Mean')
ax.axvline(med, color = 'green', label='Median')
ax.axvline(plus_one_std, color = 'black', label='plus_one_std')
ax.axvline(minus_one_std, color = 'black', ls='--', label='minus_one_std')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('VitD_levels')
ax.legend();

# %% [markdown]
# #  Doc_visits

# %%
sns.kdeplot(data = df,  x='Doc_visits');

# %%
#Add a line for the mean (red)
mean = df['Doc_visits'].mean()
#Add a line for the median (green)
med = df['Doc_visits'].median()
std = df['Doc_visits'].std()
#Add a line for for +1 std from the mean (black)
plus_one_std = mean + std
#Add a line for the - 1 std from the mean (black)
minus_one_std = mean - std
#Highlight the range between +1 and =1 std (yellow)

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(df['Doc_visits'] ,ax=ax, stat='probability')
ax.axvline(mean, color = 'red', label='Mean')
ax.axvline(med, color = 'green', label='Median')
ax.axvline(plus_one_std, color = 'black', label='plus_one_std')
ax.axvline(minus_one_std, color = 'black', ls='--', label='minus_one_std')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('Doc_visits')
ax.legend();

# %% [markdown]
# # TotalCharge

# %%
sns.kdeplot(data = df,  x='TotalCharge');

# %%
#Add a line for the mean (red)
mean = df['TotalCharge'].mean()
#Add a line for the median (green)
med = df['TotalCharge'].median()
std = df['TotalCharge'].std()
#Add a line for for +1 std from the mean (black)
plus_one_std = mean + std
#Add a line for the - 1 std from the mean (black)
minus_one_std = mean - std
#Highlight the range between +1 and =1 std (yellow)

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(df['TotalCharge'] ,ax=ax, stat='probability')
ax.axvline(mean, color = 'red', label='Mean')
ax.axvline(med, color = 'green', label='Median')
ax.axvline(plus_one_std, color = 'black', label='plus_one_std')
ax.axvline(minus_one_std, color = 'black', ls='--', label='minus_one_std')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title('TotalCharge')
ax.legend();

# %% [markdown]
# # Answer the following questions:
# Is it Discrete or Continuous?
# Does it have a skew? If so, which direction (+/-)
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %% [markdown]
# Is it Discrete or Continuous?
# VitD_Levels=Continuous,
# Doc_visits = Discrete,
# TotalCharge=Continuours

# %% [markdown]
# Does it have a skew? If so, which direction (+/-)
# VitD_Levels = Normal,
# Doc_Visits = Normal,
# TotalCharge = Positive

# %% [markdown]
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
from scipy import stats
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt
# Out:
# 3.013147515833447

# %%
kurt_d = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt_d
# Out:
# 2.9919958083381206

# %%
kurt_t = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt_t
# Out:
# 3.2650077463439384

# %%
#VitD_levels = Mesokurtic
#Doc_visits = Platykurtic
#TotalCharge = Leptokurtic
